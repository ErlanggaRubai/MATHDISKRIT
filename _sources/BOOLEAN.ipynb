# %% [markdown]
# # BOOLEAN

# %% [markdown]
# # BOOLEAN
# boolean adalah konsep dalam pemrograman, merujuk pada tipe data yang hanya memiliki dua nilai mungkin, yaitu true (benar) dan false (salah).
#
# referensi: https://revou.co/kosakata/boolean
# ## Operator Biner
# Operator biner adalah operator yang mengoperasikan dua operan dan memanipulasinya untuk menghasilkan hasil. Operator direpresentasikan oleh karakter khusus atau kata kunci dan menyediakan cara mudah untuk membandingkan nilai numerik atau rangkaian karakter.
#
# referensi:https://www.techopedia.com/definition/23953/binary-operator
# ## Operator Uner
# operasi uner adalah operasi dengan hanya satu operand, yaitu satu input.[1] Ini berbeda dengan operasi biner, yang menggunakan dua operan.[2] Contohnya adalah fungsi f : A → A, di mana A adalah himpunan. Fungsi f adalah operasi unary pada A.
#
# referensi:https://p2k.stekom.ac.id/ensiklopedia/Operasi_uner
# ## Manfaat dalam pemograman boolean
# Penggunaan Boolean search memiliki beberapa manfaat yang signifikan, terutama dalam konteks pencarian informasi di internet atau dalam database.
#
# referensi:https://blog.myskill.id/istilah-dan-tutorial/boolean-search-pengertian-manfaat-dan-cara-menggunakannya/
# ## Boolean Algebra
# Boolean Algebra adalah cabang aljabar yang berhubungan dengan operasi logika pada variabel yang hanya memiliki dua nilai, yaitu benar (True) dan salah (False), atau biasa ditandai dengan angka 1 dan 0. Ditemukan oleh matematikawan George Boole, Boolean Algebra menjadi dasar dari sistem logika yang digunakan dalam bidang komputasi, elektronik digital, dan pemrograman.
